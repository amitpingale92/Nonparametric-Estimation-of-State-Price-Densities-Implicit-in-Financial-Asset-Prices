# %%
import numpy as np
import pandas as pd

import os 
os.chdir(r'N:\Quantitative Finance')

# %%
def STATE_PRICE_DENSITY(C, STRIKE, St):
    '''
    CONSTRUCT A SPREAD POSITION
    LONG THE CALL AT K1 
    SHORT THE CALL AT K2
    '''
    N = len(C)
    P = np.zeros((N,1))
    for n in range(0, N-1):
        if(n==0):
            P[0] = 1-(St-C[0])/STRIKE[0]
        else:
            P[n] = 1-(C[n]-C[n-1])/(STRIKE[n]-STRIKE[n-1])    

    P[N-1] = 1- sum(P[N-2])
    P = sorted(P)
    SPD = (P[1:N-1]-P[0:N-2])/(STRIKE[1:N-1]-STRIKE[0:N-2])
    SPD = SPD(np.isnan(SPD)==0)
    SPD = SPD[2:-1]
    print(SPD)

# %%
def STATE_PRICE_DENSITY(C, STRIKE, St):
    '''
    CONSTRUCT A SPREAD POSITION
    LONG THE CALL AT K1 
    SHORT THE CALL AT K2
    '''
    N = len(C)
    P = np.zeros((N,1))
    for n in range(0, N-1):
        if(n==0):
            P[0] = 1-(St-C[0])/STRIKE[0]
        else:
            P[n] = 1-(C[n]-C[n-1])/(STRIKE[n]-STRIKE[n-1])    

    P[N-1] = 1- sum(P[N-2])
    P = sorted(P)
    SPD = (P[1:-1]-P[0:-2])/(STRIKE[1:-1]-STRIKE[0:-2])
    SPD = SPD(np.isnan(SPD)==0)
    SPD = SPD[2:-1]
    print(SPD)

# %%
xls = pd.ExcelFile('OPTIONS.xlsx')
DATA_1016_1 = pd.read_excel(xls, '1016')
DATA_1016 = DATA_1016_1[DATA_1016_1['Type']=='C']
DATA_1016.head()
# Out:
#          Contract Name         Last Trade Date  Strike Type  Last Price  \
# 0  SPXW191016C02000000   2019-10-14 3:21PM EDT    2000    C      968.17
# 1  SPXW191016C02400000   2019-09-19 3:37PM EDT    2400    C      492.50
# 2  SPXW191016C02425000   2019-09-19 3:37PM EDT    2425    C      583.35
# 3  SPXW191016C02690000  2019-10-14 12:08AM EDT    2690    C      239.91
# 4  SPXW191016C02715000   2019-10-09 2:59PM EDT    2715    C      211.53
#
#      Bid    Ask  Change % Change Volume Open Interest  Implied Volatility
# 0  962.2  967.9   80.62   0.0908      8            18              2.3572
# 1  563.5  569.2    0.00        -      1             2              1.0479
# 2  536.9  542.5    0.00        -      -             1              1.2573
# 3  273.8  279.2    0.00        -      -             3              0.5576
# 4  248.6  254.2    0.00        -      4             0              0.7201

# %%
#cols = ['Bid','Ask'] 
#DATA_1016['BID_ASK_AVG'] = DATA_1016['Bid']
#DATA_1016[cols].astype(float).mean(axis=1)
#DATA_1016
bid_list = [0 if element == '-' else element for element in DATA_1016['Bid']]
DATA_1016['new_Bid'] = pd.DataFrame(bid_list)
DATA_1016['BID_ASK_AVG'] = ((DATA_1016['new_Bid'] + DATA_1016['Ask'])/2)#.astype(str)
St = 2966.15
# Out:
# C:\Users\nikhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\nikhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
DATA_1016.head()
# Out:
#          Contract Name         Last Trade Date  Strike Type  Last Price  \
# 0  SPXW191016C02000000   2019-10-14 3:21PM EDT    2000    C      968.17
# 1  SPXW191016C02400000   2019-09-19 3:37PM EDT    2400    C      492.50
# 2  SPXW191016C02425000   2019-09-19 3:37PM EDT    2425    C      583.35
# 3  SPXW191016C02690000  2019-10-14 12:08AM EDT    2690    C      239.91
# 4  SPXW191016C02715000   2019-10-09 2:59PM EDT    2715    C      211.53
#
#      Bid    Ask  Change % Change Volume Open Interest  Implied Volatility  \
# 0  962.2  967.9   80.62   0.0908      8            18              2.3572
# 1  563.5  569.2    0.00        -      1             2              1.0479
# 2  536.9  542.5    0.00        -      -             1              1.2573
# 3  273.8  279.2    0.00        -      -             3              0.5576
# 4  248.6  254.2    0.00        -      4             0              0.7201
#
#    new_Bid  BID_ASK_AVG
# 0    962.2       965.05
# 1    563.5       566.35
# 2    536.9       539.70
# 3    273.8       276.50
# 4    248.6       251.40

# %%
SPD_1016 = STATE_PRICE_DENSITY(DATA_1016['BID_ASK_AVG'],DATA_1016['Strike'],St)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-43fe1dd6002c> in <module>()
# ----> 1 SPD_1016 = STATE_PRICE_DENSITY(DATA_1016['BID_ASK_AVG'],DATA_1016['Strike'],St)
#
# <ipython-input-2-befb4bbf3c87> in STATE_PRICE_DENSITY(C, STRIKE, St)
#      15     P[N-1] = 1- sum(P[N-2])
#      16     P = sorted(P)
# ---> 17     SPD = (P[1:N-1]-P[0:N-2])/(STRIKE[1:N-1]-STRIKE[0:N-2])
#      18     SPD = SPD(np.isnan(SPD)==0)
#      19     SPD = SPD[2:-1]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
